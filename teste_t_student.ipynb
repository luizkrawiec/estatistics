# %% [markdown]
# <a href="https://colab.research.google.com/github/luizkrawiec/estatistics/blob/main/teste_t_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Teste t student (duas amostras independentes)**
#
# amostras pequenas (menor que 30)
#
# Não necessita conhecimento do desvio padrão

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels
from statsmodels.stats.diagnostic import lilliefors

# %%
enem_sp = pd.read_csv('/content/enem_2019_tratado.csv', sep=',', encoding='iso-8859-1')

# %%
enem_sp.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL    RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1   parda
# 1     1,90E+11               São Paulo     17    F                1   parda
# 2     1,90E+11   São Bernardo do Campo     19    M                1   parda
# 3     1,90E+11              Embu-Guaçu     17    F                1   parda
# 4     1,90E+11               Guarulhos     23    F                1  branca
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0                 1                1  não_respondeu         NaN  ...   600.2
# 1                 1                2        privada  15567761.0  ...   731.8
# 2                 1                2        pública  35904958.0  ...   393.2
# 3                 1                2        pública         NaN  ...   419.2
# 4                 1                1  não_respondeu         NaN  ...   796.1
#
# ...

# %% [markdown]
# # **Objetivo:**
#
# Analisar a diferença entre as medias de dois componentes de redação do colégio y

# %%
colegio_y = enem_sp.loc[enem_sp.CO_ESCOLA == 35151506.0]

# %%
colegio_y.head()
# Out:
#       NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 492       1,90E+11               São Paulo     17    F                1
# 7910      1,90E+11               São Paulo     18    F                1
# 14367     1,90E+11               São Paulo     17    M                1
# 22519     1,90E+11               São Paulo     17    F                1
# 58184     1,90E+11               São Paulo     17    M                1
#
#          RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO   ESCOLA   CO_ESCOLA  ...  \
# 492    branca                 1                2  privada  35151506.0  ...
# 7910   branca                 1                2  privada  35151506.0  ...
# 14367  branca                 1                2  privada  35151506.0  ...
# 22519   preta                 1                2  privada  35151506.0  ...
# 58184  branca                 1                2  privada  35151506.0  ...
#
#       NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# ...

# %%
colegio_y.shape
# Out:
# (30, 28)

# %% [markdown]
# ## **Analisar a classificação das variáveis**

# %%
colegio_y.dtypes
# Out:
# NU_INSCRICAO                object
# NO_MUNICIPIO_RESIDENCIA     object
# IDADE                        int64
# SEXO                        object
# TP_ESTADO_CIVIL              int64
# RACA                        object
# TP_NACIONALIDADE             int64
# TP_ST_CONCLUSAO              int64
# ESCOLA                      object
# CO_ESCOLA                  float64
# NO_MUNICIPIO_ESC            object
# TP_PRESENCA_CN               int64
# TP_PRESENCA_CH               int64
# TP_PRESENCA_LC               int64
# TP_PRESENCA_MT               int64
# NOTA_CN                    float64
# NOTA_CH                    float64
# NOTA_LC                    float64
# NOTA_MT                    float64
# TP_LINGUA                   object
# TP_STATUS_REDACAO          float64
# COMP1                      float64
# COMP2                      float64
# COMP3                      float64
# COMP4                      float64
# COMP5                      float64
# NOTA_REDACAO               float64
# ...

# %% [markdown]
# ## **Analisar valores missing**

# %%
colegio_y.isnull().sum()
# Out:
# NU_INSCRICAO               0
# NO_MUNICIPIO_RESIDENCIA    0
# IDADE                      0
# SEXO                       0
# TP_ESTADO_CIVIL            0
# RACA                       0
# TP_NACIONALIDADE           0
# TP_ST_CONCLUSAO            0
# ESCOLA                     0
# CO_ESCOLA                  0
# NO_MUNICIPIO_ESC           0
# TP_PRESENCA_CN             0
# TP_PRESENCA_CH             0
# TP_PRESENCA_LC             0
# TP_PRESENCA_MT             0
# NOTA_CN                    0
# NOTA_CH                    0
# NOTA_LC                    0
# NOTA_MT                    0
# TP_LINGUA                  0
# TP_STATUS_REDACAO          0
# COMP1                      0
# COMP2                      0
# COMP3                      0
# COMP4                      0
# COMP5                      0
# NOTA_REDACAO               0
# INTERNET                   0
# dtype: int64

# %%
grafico = px.box(colegio_y, y='COMP3')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.box(colegio_y, y='COMP5')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Analisar a Normalidade**

# %% [markdown]
# **Critérios:**
#
# Nível de Significância de 0,05 ou 5% (Mais Utilizado)
#
# Quando p>0,05(distribuiçaõ normal)

# %%
#teste Shapiro-wilk
stats.shapiro(colegio_y.COMP3)
# Out:
# ShapiroResult(statistic=0.916003406047821, pvalue=0.02115193009376526)

# %%
#Teste Lilliefors (kolmogorov - Sminorv)
statsmodels.stats.diagnostic.lilliefors(colegio_y.COMP3, dist='norm')
# Out:
# (0.20710628123776997, 0.0022752873084563707)

# %%
sns.histplot(colegio_y,x='COMP5', bins=6,color='red', kde=True, stat='probability')
# Out:
# <Axes: xlabel='COMP5', ylabel='Probability'>

# %%
sns.histplot(colegio_y,x='COMP3', bins=6,color='green', kde=True, stat='probability')
# Out:
# <Axes: xlabel='COMP3', ylabel='Probability'>
